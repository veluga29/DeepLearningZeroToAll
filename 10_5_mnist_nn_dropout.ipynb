# %%
import tensorflow as tf
import numpy as np
import random

# %%
random.seed(235)
learning_rate = 0.001
batch_size = 100
training_epochs = 15
nb_classes = 10
drop_rate = 0.3

# %%
(x_train, y_train), (x_test2, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train = x_train.reshape(x_train.shape[0], 28 * 28)
x_test = x_test2.reshape(x_test2.shape[0], 28 * 28)

# %%
y_train = tf.keras.utils.to_categorical(y_train, nb_classes)
y_test = tf.keras.utils.to_categorical(y_test, nb_classes)

# %%
tf.model = tf.keras.Sequential()

# %%
# Xavier 초기화 진행 (= glorot normal) 및 dropout 진행
tf.model.add(tf.keras.layers.Dense(input_dim=784, units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units=nb_classes, kernel_initializer='glorot_normal', activation='softmax'))
tf.model.compile(loss='categorical_crossentropy', 
                 optimizer=tf.keras.optimizers.Adam(lr=learning_rate), metrics=['accuracy'])
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,195,018
# Trainable params: 1,195,018
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = tf.model.fit(x_train, y_train, batch_size=batch_size, epochs=training_epochs)
# Out:
# Train on 60000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 45s 746us/sample - loss: 2.0608 - accuracy: 0.7624
# Epoch 2/15
# 60000/60000 [==============================] - 41s 681us/sample - loss: 0.3707 - accuracy: 0.8958
# Epoch 3/15
# 60000/60000 [==============================] - 41s 687us/sample - loss: 0.2740 - accuracy: 0.9245
# Epoch 4/15
# 60000/60000 [==============================] - 41s 684us/sample - loss: 0.2238 - accuracy: 0.9382
# Epoch 5/15
# 60000/60000 [==============================] - 41s 692us/sample - loss: 0.2089 - accuracy: 0.9431
# Epoch 6/15
# 60000/60000 [==============================] - 43s 710us/sample - loss: 0.1880 - accuracy: 0.9501
# Epoch 7/15
# 60000/60000 [==============================] - 42s 705us/sample - loss: 0.1863 - accuracy: 0.9509
# Epoch 8/15
# 60000/60000 [==============================] - 41s 691us/sample - loss: 0.1793 - accuracy: 0.9535
# Epoch 9/15
# 60000/60000 [==============================] - 41s 683us/sample - loss: 0.1765 - accuracy: 0.9548
# Epoch 10/15
# 60000/60000 [==============================] - 41s 689us/sample - loss: 0.1749 - accuracy: 0.9561
# Epoch 11/15
# 60000/60000 [==============================] - 41s 687us/sample - loss: 0.1825 - accuracy: 0.9553
# Epoch 12/15
# 60000/60000 [==============================] - 41s 689us/sample - loss: 0.1726 - accuracy: 0.9577
# Epoch 13/15
# 60000/60000 [==============================] - 41s 690us/sample - loss: 0.1718 - accuracy: 0.9590
# Epoch 14/15
# 60000/60000 [==============================] - 41s 681us/sample - loss: 0.1629 - accuracy: 0.9610
# Epoch 15/15
# 60000/60000 [==============================] - 42s 695us/sample - loss: 0.1671 - accuracy: 0.9602

# %%
# Prediction
y_predicted = tf.model.predict(x_test)
for x in range(0, 10):
    random_index = random.randint(0, x_test.shape[0]-1)
    print("index: ", random_index,
          "actual y: ", np.argmax(y_test[random_index]),
          "predicted y: ", np.argmax(y_predicted[random_index]))
# Out:
# index:  5682 actual y:  5 predicted y:  5
# index:  8432 actual y:  1 predicted y:  1
# index:  608 actual y:  0 predicted y:  0
# index:  4078 actual y:  9 predicted y:  9
# index:  1247 actual y:  9 predicted y:  5
# index:  1501 actual y:  9 predicted y:  9
# index:  362 actual y:  2 predicted y:  2
# index:  4121 actual y:  8 predicted y:  8
# index:  2591 actual y:  7 predicted y:  7
# index:  900 actual y:  1 predicted y:  1

# %%
# print loss & accuracy
evaluation = tf.model.evaluate(x_test, y_test)
print('loss: ', evaluation[0])
print('accuracy', evaluation[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# loss:  0.12685777874029408
# accuracy 0.9719
