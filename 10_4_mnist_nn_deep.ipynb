# %%
import tensorflow as tf
import numpy as np
import random

# %%
random.seed(234)
learning_rate = 0.001
batch_size = 100
training_epochs = 15
nb_classes = 10

# %%
(x_train, y_train), (x_test2, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train = x_train.reshape(x_train.shape[0], 28 * 28)
x_test = x_test2.reshape(x_test2.shape[0], 28 * 28)

# %%
y_train = tf.keras.utils.to_categorical(y_train, nb_classes)
y_test = tf.keras.utils.to_categorical(y_test, nb_classes)

# %%
tf.model = tf.keras.Sequential()

# %%
# Xavier 초기화 진행 (= glorot normal) 및 보다 더 깊고 넓은 신경망 구성
tf.model.add(tf.keras.layers.Dense(input_dim=784, units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dense(units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dense(units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dense(units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dense(units=nb_classes, kernel_initializer='glorot_normal', activation='softmax'))
tf.model.compile(loss='categorical_crossentropy', 
                 optimizer=tf.keras.optimizers.Adam(lr=learning_rate), metrics=['accuracy'])
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,195,018
# Trainable params: 1,195,018
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = tf.model.fit(x_train, y_train, batch_size=batch_size, epochs=training_epochs)
# Out:
# Train on 60000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 41s 689us/sample - loss: 1.0219 - accuracy: 0.9052A: 32s - loss: 2.7328 - accura - E - ETA: 27s - loss: 2.2168 - accuracy - ETA: 26s - loss: 2 - ETA: 5s - ETA: 1s - l
# Epoch 2/15
# 60000/60000 [==============================] - 38s 629us/sample - loss: 0.1334 - accuracy: 0.9607- loss: 0.1340 - accura - ETA: 0s - loss: 0.1334 - accu
# Epoch 3/15
# 60000/60000 [==============================] - 39s 652us/sample - loss: 0.1025 - accuracy: 0.9692
# Epoch 4/15
# 60000/60000 [==============================] - 39s 655us/sample - loss: 0.0848 - accuracy: 0.9747
# Epoch 5/15
# 60000/60000 [==============================] - 40s 664us/sample - loss: 0.0776 - accuracy: 0.9757
# Epoch 6/15
# 60000/60000 [==============================] - 31s 518us/sample - loss: 0.0713 - accuracy: 0.97915s - ETA: 25s - loss: 0 - ETA: 24
# Epoch 7/15
# 60000/60000 [==============================] - 38s 630us/sample - loss: 0.0732 - accuracy: 0.9789- loss:
# Epoch 8/15
# 60000/60000 [==============================] - 45s 745us/sample - loss: 0.0615 - accuracy: 0.9822
# Epoch 9/15
# 60000/60000 [==============================] - 47s 776us/sample - loss: 0.0607 - accuracy: 0.9830
# Epoch 10/15
# 60000/60000 [==============================] - 40s 670us/sample - loss: 0.0567 - accuracy: 0.9838
# Epoch 11/15
# 60000/60000 [==============================] - 46s 763us/sample - loss: 0.0506 - accuracy: 0.9859- loss: 0.0505 - accuracy: 0.98
# Epoch 12/15
# 60000/60000 [==============================] - 42s 699us/sample - loss: 0.0474 - accuracy: 0.9867
# Epoch 13/15
# 60000/60000 [==============================] - 43s 721us/sample - loss: 0.0538 - accuracy: 0.9857- loss: 0.0 - ETA: 0s - loss: 0.0538 -
# Epoch 14/15
# 60000/60000 [==============================] - 38s 626us/sample - loss: 0.0469 - accuracy: 0.9876
# Epoch 15/15
# 60000/60000 [==============================] - 39s 655us/sample - loss: 0.0456 - accuracy: 0.9884

# %%
# Prediction
y_predicted = tf.model.predict(x_test)
for x in range(0, 10):
    random_index = random.randint(0, x_test.shape[0]-1)
    print("index: ", random_index,
          "actual y: ", np.argmax(y_test[random_index]),
          "predicted y: ", np.argmax(y_predicted[random_index]))
# Out:
# index:  5600 actual y:  7 predicted y:  7
# index:  4337 actual y:  1 predicted y:  1
# index:  943 actual y:  6 predicted y:  6
# index:  9510 actual y:  2 predicted y:  2
# index:  6738 actual y:  4 predicted y:  4
# index:  8282 actual y:  7 predicted y:  7
# index:  7872 actual y:  8 predicted y:  8
# index:  3755 actual y:  9 predicted y:  9
# index:  4279 actual y:  2 predicted y:  2
# index:  5680 actual y:  8 predicted y:  8

# %%
# print loss & accuracy
evaluation = tf.model.evaluate(x_test, y_test)
print('loss: ', evaluation[0])
print('accuracy', evaluation[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# loss:  0.12497328520979353
# accuracy 0.9731
