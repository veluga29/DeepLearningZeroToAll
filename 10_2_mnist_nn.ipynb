# %%
import tensorflow as tf
import numpy as np
import random

# %%
random.seed(777)  # 재사용을 가능하게 하기 위해
learning_rate = 0.001
batch_size = 100
training_epochs = 15
nb_classes = 10

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)
# Out:
# (60000, 28, 28)

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1] * x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1] * x_test.shape[2])

# %%
# 원핫 인코딩 적용
y_train = tf.keras.utils.to_categorical(y_train, nb_classes)
y_test = tf.keras.utils.to_categorical(y_test, nb_classes)

# %%
# 출력 이전 layer를 제외한 나머지 layer는 ReLU 활성화 함수 적용
tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(input_dim=784, units=256, activation='relu'))
tf.model.add(tf.keras.layers.Dense(units=256, activation='relu'))
tf.model.add(tf.keras.layers.Dense(units=nb_classes, activation='softmax'))
tf.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=learning_rate), metrics=['accuracy'])
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# ...
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.model.fit(x_train, y_train, batch_size=batch_size, epochs=training_epochs)
# Out:
# Train on 60000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 11s 188us/sample - loss: 2.5823 - accuracy: 0.8865
# Epoch 2/15
# 60000/60000 [==============================] - 7s 121us/sample - loss: 0.4189 - accuracy: 0.9439
# Epoch 3/15
# 60000/60000 [==============================] - 8s 134us/sample - loss: 0.2639 - accuracy: 0.9575 - - ETA: 1s - loss: 0.2604 - accuracy: 0.95 -
# Epoch 4/15
# 60000/60000 [==============================] - 9s 155us/sample - loss: 0.1949 - accuracy: 0.9647 - loss: 0.1928
# Epoch 5/15
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.1712 - accuracy: 0.9690
# Epoch 6/15
# 60000/60000 [==============================] - 9s 155us/sample - loss: 0.1401 - accuracy: 0.9722
# Epoch 7/15
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.1245 - accuracy: 0.9742
# Epoch 8/15
# ...

# %%
# prediction
y_predict = tf.model.predict(x_test)
for i in range(10):
    random_idx = random.randint(0, x_test.shape[0] - 1)
    print("index: ", random_idx,
          "actual y: ", np.argmax(y_test[random_idx]),
          "predicted y: ", np.argmax(y_predict[random_idx]))
# Out:
# index:  3757 actual y:  8 predicted y:  8
# index:  7304 actual y:  5 predicted y:  5
# index:  7300 actual y:  7 predicted y:  7
# index:  6039 actual y:  9 predicted y:  9
# index:  9429 actual y:  3 predicted y:  3
# index:  4420 actual y:  5 predicted y:  5
# index:  5507 actual y:  2 predicted y:  2
# index:  8809 actual y:  1 predicted y:  1
# index:  654 actual y:  5 predicted y:  5
# index:  7302 actual y:  8 predicted y:  8

# %%
evaluation = tf.model.evaluate(x_test, y_test)
print("loss: ", evaluation[0])
print("accuracy: ", evaluation[1])
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...
