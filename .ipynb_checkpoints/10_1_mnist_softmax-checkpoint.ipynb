# %%
import tensorflow as tf

# %%
learning_rate = 0.001
batch_size = 100
training_epochs = 15
nb_classes = 10

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# normalizing data
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
# data shape 변경하기
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1] * x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1] * x_test.shape[2])
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
# y 데이터에 대하여 원-핫 인코딩 진행
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=10, input_dim=784, activation='softmax'))
tf.model.compile(loss='categorical_crossentropy', optimizer=tf.optimizers.Adam(0.001), metrics=['accuracy'])
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                7850
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = tf.model.fit(x_train, y_train, batch_size=batch_size, epochs=training_epochs)
# Out:
# Train on 60000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.6351 - accuracy: 0.8378
# Epoch 2/15
# 60000/60000 [==============================] - 4s 61us/sample - loss: 0.3473 - accuracy: 0.9061
# Epoch 3/15
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.3100 - accuracy: 0.9142
# Epoch 4/15
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.2928 - accuracy: 0.9185
# Epoch 5/15
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.2822 - accuracy: 0.9213
# Epoch 6/15
# 60000/60000 [==============================] - 4s 75us/sample - loss: 0.2749 - accuracy: 0.9226
# Epoch 7/15
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.2698 - accuracy: 0.9243
# Epoch 8/15
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.2654 - accuracy: 0.9261
# Epoch 9/15
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.2621 - accuracy: 0.9270
# Epoch 10/15
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.2595 - accuracy: 0.9273
# Epoch 11/15
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.2571 - accuracy: 0.9290
# Epoch 12/15
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.2545 - accuracy: 0.9293
# Epoch 13/15
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.2526 - accuracy: 0.9301
# Epoch 14/15
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.2510 - accuracy: 0.9307
# Epoch 15/15
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.2497 - accuracy: 0.9312

# %%
predictions = tf.model.predict_classes(x_test)
print('Prediction: \n', predictions)
# Out:
# Prediction:
#  [7 2 1 ... 4 5 6]

# %%
score = tf.model.evaluate(x_train, y_train)
print('Accuracy: ', score[1])
# Out:
# 60000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Accuracy:  0.9325167
