# %%
import numpy as np
import tensorflow as tf
import random

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_test = x_test / 255
x_train = x_train / 255
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# %%
# 원핫 인코딩
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
learning_rate = 0.001
training_epochs = 12
batch_size = 128

# %%
tf.model = tf.keras.Sequential()

# %%
# Layer 1
tf.model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3, 3), input_shape=(28, 28, 1), activation='relu'))
tf.model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

# %%
# Layer 2
tf.model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
tf.model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

# %%
# Layer 3 Fully Connected
tf.model.add(tf.keras.layers.Flatten())
tf.model.add(tf.keras.layers.Dense(units=10, kernel_initializer='glorot_normal', activation='softmax'))

# %%
tf.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=learning_rate), metrics=['accuracy'])

# %%
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                8010
# =================================================================
# Total params: 12,810
# Trainable params: 12,810
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.model.fit(x_train, y_train, batch_size=batch_size, epochs=training_epochs)
# Out:
# Train on 60000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 63s 1ms/sample - loss: 0.3764 - accuracy: 0.8963
# Epoch 2/12
# 60000/60000 [==============================] - 55s 921us/sample - loss: 0.0902 - accuracy: 0.9732
# Epoch 3/12
# 60000/60000 [==============================] - 54s 907us/sample - loss: 0.0665 - accuracy: 0.9795
# Epoch 4/12
# 60000/60000 [==============================] - 54s 901us/sample - loss: 0.0550 - accuracy: 0.9826
# Epoch 5/12
# 60000/60000 [==============================] - 56s 929us/sample - loss: 0.0485 - accuracy: 0.9852
# Epoch 6/12
# 60000/60000 [==============================] - 60s 1ms/sample - loss: 0.0433 - accuracy: 0.9862
# Epoch 7/12
# 60000/60000 [==============================] - 55s 914us/sample - loss: 0.0389 - accuracy: 0.9883
# Epoch 8/12
# 60000/60000 [==============================] - 55s 911us/sample - loss: 0.0357 - accuracy: 0.9892
# Epoch 9/12
# 60000/60000 [==============================] - 55s 920us/sample - loss: 0.0318 - accuracy: 0.9900
# Epoch 10/12
# 60000/60000 [==============================] - 55s 923us/sample - loss: 0.0291 - accuracy: 0.9912
# Epoch 11/12
# 60000/60000 [==============================] - 55s 919us/sample - loss: 0.0268 - accuracy: 0.9919
# Epoch 12/12
# 60000/60000 [==============================] - 56s 940us/sample - loss: 0.0246 - accuracy: 0.9926

# %%
y_predicted = tf.model.predict(x_test)
for x in range(0, 10):
    random_index = random.randint(0, x_test.shape[0]-1)
    print("index: ", random_index,
          "actual y: ", np.argmax(y_test[random_index]),
          "predicted y: ", np.argmax(y_predicted[random_index]))
# Out:
# index:  1113 actual y:  5 predicted y:  5
# index:  8011 actual y:  4 predicted y:  4
# index:  8227 actual y:  9 predicted y:  9
# index:  552 actual y:  0 predicted y:  0
# index:  4710 actual y:  2 predicted y:  2
# index:  7352 actual y:  5 predicted y:  5
# index:  1161 actual y:  6 predicted y:  6
# index:  5738 actual y:  1 predicted y:  1
# index:  4108 actual y:  5 predicted y:  5
# index:  6570 actual y:  3 predicted y:  3

# %%
evaluation = tf.model.evaluate(x_test, y_test)
print('loss: ', evaluation[0])
print('accuracy', evaluation[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# loss:  0.03467622825384024
# accuracy 0.9888
