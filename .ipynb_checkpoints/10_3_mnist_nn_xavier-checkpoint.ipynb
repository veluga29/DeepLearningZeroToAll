# %%
import tensorflow as tf
import numpy as np
import random

# %%
random.seed(234)
learning_rate = 0.001
batch_size = 100
training_epochs = 15
nb_classes = 10

# %%
(x_train, y_train), (x_test2, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train = x_train.reshape(x_train.shape[0], 28 * 28)
x_test = x_test2.reshape(x_test2.shape[0], 28 * 28)

# %%
y_train = tf.keras.utils.to_categorical(y_train, nb_classes)
y_test = tf.keras.utils.to_categorical(y_test, nb_classes)

# %%
tf.model = tf.keras.Sequential()

# %%
# Xavier 초기화 진행 (= glorot normal)
tf.model.add(tf.keras.layers.Dense(input_dim=784, units=256, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dense(units=256, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dense(units=nb_classes, kernel_initializer='glorot_normal', activation='softmax'))
tf.model.compile(loss='categorical_crossentropy', 
                 optimizer=tf.keras.optimizers.Adam(lr=learning_rate), metrics=['accuracy'])
tf.model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = tf.model.fit(x_train, y_train, batch_size=batch_size, epochs=training_epochs)
# Out:
# Train on 60000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 12s 201us/sample - loss: 2.3947 - accuracy: 0.8968- loss: 2.4045 - accuracy: 0.89
# Epoch 2/15
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.4238 - accuracy: 0.9461
# Epoch 3/15
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.2979 - accuracy: 0.9582- loss: 0 - ETA: 3s - - ETA: 1s - loss: 0.2958 - accuracy:  - E
# Epoch 4/15
# 60000/60000 [==============================] - 9s 156us/sample - loss: 0.2046 - accuracy: 0.9659 - loss: 0.2027 - ac - ETA: 0s - loss: 0.2046 - accuracy
# Epoch 5/15
# 60000/60000 [==============================] - 9s 158us/sample - loss: 0.1550 - accuracy: 0.9702
# Epoch 6/15
# 60000/60000 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.97 - 9s 158us/sample - loss: 0.1377 - accuracy: 0.9737
# Epoch 7/15
# 60000/60000 [==============================] - 10s 162us/sample - loss: 0.1093 - accuracy: 0.9767- loss: 0.1044 -  - ETA: 0s -
# Epoch 8/15
# 60000/60000 [==============================] - 9s 155us/sample - loss: 0.0956 - accuracy: 0.9793
# Epoch 9/15
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.0999 - accuracy: 0.9777- loss: 0.0912  - ETA - ETA: 0s - loss: 0.1000 - accuracy: 0.
# Epoch 10/15
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.0773 - accuracy: 0.9805- los
# Epoch 11/15
# 60000/60000 [==============================] - 10s 171us/sample - loss: 0.0849 - accuracy: 0.9794- loss: 0.0792 - accuracy - ETA: 0s - loss: 0.0852 - ac
# Epoch 12/15
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.0719 - accuracy: 0.9813
# Epoch 13/15
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.0687 - accuracy: 0.9833
# Epoch 14/15
# 60000/60000 [==============================] - 10s 158us/sample - loss: 0.0774 - accuracy: 0.9806
# Epoch 15/15
# 60000/60000 [==============================] - 9s 157us/sample - loss: 0.0635 - accuracy: 0.9839 - ETA: 2s - loss: 0.0636  - ETA: 1s - los - ETA: 0s - l

# %%
# Prediction
y_predicted = tf.model.predict(x_test)
for x in range(0, 10):
    random_index = random.randint(0, x_test.shape[0]-1)
    print("index: ", random_index,
          "actual y: ", np.argmax(y_test[random_index]),
          "predicted y: ", np.argmax(y_predicted[random_index]))
# Out:
# index:  4555 actual y:  9 predicted y:  9
# index:  4655 actual y:  1 predicted y:  1
# index:  295 actual y:  4 predicted y:  4
# index:  6211 actual y:  0 predicted y:  0
# index:  4888 actual y:  5 predicted y:  5
# index:  1820 actual y:  1 predicted y:  1
# index:  1858 actual y:  6 predicted y:  6
# index:  9621 actual y:  0 predicted y:  0
# index:  4957 actual y:  0 predicted y:  0
# index:  4011 actual y:  8 predicted y:  8

# %%
# print loss & accuracy
evaluation = tf.model.evaluate(x_test, y_test)
print('loss: ', evaluation[0])
print('accuracy', evaluation[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# loss:  0.2611253833826022
# accuracy 0.9638
